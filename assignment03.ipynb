# %% [markdown]
# Name : Kim So Young
# Student ID : 20146420
# assignment 03

# %% [markdown]
# github link : https://github.com/whale22/4-2cmVisionMCLR

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs

# %% [markdown]
# import block, using libraries

# %%
k=3 #number of clusters
X, y_true = make_blobs(n_samples=300, centers=k,
                       cluster_std=0.60, random_state=0)
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %% [markdown]
# demonstrate clusters' number(k), kmean states

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=60, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# draw k-mean graph. You can see k clusters.
